# %% [markdown]
# - 参考文档：
#     - https://www.liaoxuefeng.com/wiki/1016959663602400/1017784095418144
#     - https://www.runoob.com/python/python-xml.html

# %% [markdown]
# ![xml.png](attachment:xml.png)

# %% [markdown]
# ![etree.png](attachment:etree.png)

# %% [markdown]
# ![xml%E6%96%87%E4%BB%B6%E5%86%99%E5%85%A5.png](attachment:xml%E6%96%87%E4%BB%B6%E5%86%99%E5%85%A5.png)

# %%
# 案例 v03：

# %% [markdown]
# ![%E8%BF%BD%E5%8A%A0_%E6%A1%88%E4%BE%8B.png](attachment:%E8%BF%BD%E5%8A%A0_%E6%A1%88%E4%BE%8B.png)

# %%
# 案例v04:

# %% [markdown]
# ![%E6%A1%88%E4%BE%8Bv04.png](attachment:%E6%A1%88%E4%BE%8Bv04.png)

# %%
# 案例v06:

# %% [markdown]
# ![%E6%A1%88%E4%BE%8Bv06.png](attachment:%E6%A1%88%E4%BE%8Bv06.png)
