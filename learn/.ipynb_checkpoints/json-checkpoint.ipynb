# %% [markdown]
# ![json.png](attachment:json.png)

# %% [markdown]
# ![json1.png](attachment:json1.png)

# %%
# 案例v07

# %% [markdown]
# ![%E6%A1%88%E4%BE%8Bv07.png](attachment:%E6%A1%88%E4%BE%8Bv07.png)

# %%
# 案例v08：对json文件的操作

# %% [markdown]
# ![%E6%A1%88%E4%BE%8Bv08.png](attachment:%E6%A1%88%E4%BE%8Bv08.png)
